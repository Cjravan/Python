# %%
# A theatre sells batches of 1 to 4 tickets per sale (if available).
# Initially there are 200 tickets. Write a Python program that repeatedly tells the user how many tickets are left,
# asks for how many tickets the user wants to buy, indicates minimum and maximum numbers to buy, and reads the user's input.
# This continues until all tickets have been sold. At the end, the program prints how many sales transactions have been performed.
# For example, we might have the following interaction:


# 200 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 3
# 197 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# (...)

# 2 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 2
# 2
# 86 sales transactions

# (You may assume that the user enters the data correctly, i.e., all values are integers between the current minimum and maximum numbers they may buy.)

# %%
tickets_remaining = 200
sales_transactions = 0

while tickets_remaining > 0:
    print(f"{tickets_remaining} tickets remaining")
    print("How many do you want to buy?")
    print(f"Minimum 1, maximum {min(tickets_remaining, 4)}")

    num_tickets = int(input())

    while num_tickets < 1 or num_tickets > min(tickets_remaining, 4):
        print("Invalid number of tickets. Please try again.")
        num_tickets = int(input())

    tickets_remaining -= num_tickets
    sales_transactions += 1

print(f"{sales_transactions} sales transactions")
# Out:
# 200 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 196 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 192 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 188 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 184 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 180 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 176 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 172 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 168 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 164 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 160 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# 156 tickets remaining
# How many do you want to buy?
# Minimum 1, maximum 4
# 4
# ...

# %%
# Write a Python program that reads a series of lines one by one from the keyboard 
# (ending by an empty line) and, at the end, outputs the number of times that the first line occurred.
# For example, if it reads

# hello
# world
# We say hello
# hello
# Birkbeck
# hello

# it would output 3 since the first line ("hello") occurred three times.

# You may assume that the user enters at least two non-empty lines before the empty line.

# %%
lines = []
first_line = None

# Read lines until an empty line is entered
while True:
    line = input()
    if line == '':
        break

    lines.append(line)

    if first_line is None:
        first_line = line

count = sum(1 for line in lines if line == first_line)

print(count)
# Out:
# 0

# %%
# Write a Python program that reads a series of positive integer numbers one by one from the keyboard
# (ending by -1) and, at the end, outputs 'Yes' once if the numbers were in (strictly) ascending order,
# otherwise it outputs 'No' (again, only once and at the end).

# For example, it should output 'Yes' for 3, 5, 8, 15, 22, -1, and for 10, 20, 45, -1;
# but ‘No’ for 3, 5, 4, 8, -1, for 1, 2, 1, -1, and for 3, 5, 5, 8, -1.

# You may assume that the user enters at least two positive numbers before the -1 and 
# that there are no incorrect inputs.

# %%
previous_num = None
ascending = True

while True:
    num = int(input())

    if num == -1:
        break

    if previous_num is not None and num <= previous_num:
        ascending = False

    previous_num = num

if ascending:
    print('Yes')
else:
    print('No')
# Out:
# 5
# 6
# -1
# Yes
